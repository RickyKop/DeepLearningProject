# %% [markdown]
# Installing Libraries

# %%
# final import versions

# !pip install torch
# !pip install "stable-baselines3[extra]>=2.0.0a4"
# !pip install "rl_zoo3"
# cells will automatically re-import modules when executing a new cell
# %load_ext autoreload
# %autoreload 2
# Out:
# Requirement already satisfied: torch in /home/alastor/anaconda3/lib/python3.12/site-packages (2.5.1)
# Requirement already satisfied: filelock in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (3.1.0)
# Requirement already satisfied: setuptools in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (69.5.1)
# Requirement already satisfied: sympy==1.13.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: stable-baselines3>=2.0.0a4 in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.5.0a0)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.0.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.26.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.5.1)
# Requirement already satisfied: cloudpickle in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.2.1)
# Requirement already satisfied: pandas in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.2.2)
# Requirement already satisfied: matplotlib in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.8.4)
# Requirement already satisfied: opencv-python in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (4.10.0.84)
# Requirement already satisfied: pygame in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.18.0)
# Requirement already satisfied: psutil in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (5.9.0)
# Requirement already satisfied: tqdm in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (4.66.4)
# Requirement already satisfied: rich in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (13.3.5)
# Requirement already satisfied: ale-py>=0.9.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (0.10.1)
# Requirement already satisfied: pillow in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (10.3.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.0.4)
# Requirement already satisfied: absl-py>=0.4 in /home/alastor/anaconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/alastor/anaconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.68.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/alastor/anaconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.4.1)
# Requirement already satisfied: packaging in /home/alastor/anaconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (23.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /home/alastor/anaconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (69.5.1)
# Requirement already satisfied: six>1.9 in /home/alastor/anaconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.0.3)
# Requirement already satisfied: filelock in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.13.1)
# Requirement already satisfied: networkx in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.2.1)
# Requirement already satisfied: jinja2 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.4)
# Requirement already satisfied: fsspec in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/alastor/anaconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/alastor/anaconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/alastor/anaconda3/lib/python3.12/site-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2023.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a4) (0.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.1.3)
# Requirement already satisfied: rl_zoo3 in /home/alastor/anaconda3/lib/python3.12/site-packages (2.4.0)
# Requirement already satisfied: sb3-contrib<3.0,>=2.4.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from rl_zoo3) (2.4.0)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from rl_zoo3) (1.0.0)
# Requirement already satisfied: huggingface-sb3<4.0,>=3.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from rl_zoo3) (3.0)
# Requirement already satisfied: tqdm in /home/alastor/anaconda3/lib/python3.12/site-packages (from rl_zoo3) (4.66.4)
# Requirement already satisfied: rich in /home/alastor/anaconda3/lib/python3.12/site-packages (from rl_zoo3) (13.3.5)
# Requirement already satisfied: optuna>=3.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from rl_zoo3) (4.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from rl_zoo3) (6.0.1)
# Requirement already satisfied: pytablewriter~=1.2 in /home/alastor/anaconda3/lib/python3.12/site-packages (from rl_zoo3) (1.2.0)
# Requirement already satisfied: shimmy~=2.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from rl_zoo3) (2.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3) (0.0.4)
# Requirement already satisfied: huggingface-hub~=0.8 in /home/alastor/anaconda3/lib/python3.12/site-packages (from huggingface-sb3<4.0,>=3.0->rl_zoo3) (0.26.3)
# Requirement already satisfied: wasabi in /home/alastor/anaconda3/lib/python3.12/site-packages (from huggingface-sb3<4.0,>=3.0->rl_zoo3) (1.1.3)
# Requirement already satisfied: alembic>=1.5.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from optuna>=3.0->rl_zoo3) (1.14.0)
# Requirement already satisfied: colorlog in /home/alastor/anaconda3/lib/python3.12/site-packages (from optuna>=3.0->rl_zoo3) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from optuna>=3.0->rl_zoo3) (23.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /home/alastor/anaconda3/lib/python3.12/site-packages (from optuna>=3.0->rl_zoo3) (2.0.30)
# Requirement already satisfied: setuptools>=38.3.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from pytablewriter~=1.2->rl_zoo3) (69.5.1)
# Requirement already satisfied: DataProperty<2,>=1.0.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from pytablewriter~=1.2->rl_zoo3) (1.0.1)
# Requirement already satisfied: mbstrdecoder<2,>=1.0.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from pytablewriter~=1.2->rl_zoo3) (1.1.3)
# Requirement already satisfied: pathvalidate<4,>=2.3.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from pytablewriter~=1.2->rl_zoo3) (3.2.1)
# Requirement already satisfied: tabledata<2,>=1.3.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from pytablewriter~=1.2->rl_zoo3) (1.3.3)
# Requirement already satisfied: tcolorpy<1,>=0.0.5 in /home/alastor/anaconda3/lib/python3.12/site-packages (from pytablewriter~=1.2->rl_zoo3) (0.1.6)
# Requirement already satisfied: typepy<2,>=1.3.2 in /home/alastor/anaconda3/lib/python3.12/site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3) (1.3.2)
# Requirement already satisfied: stable-baselines3<3.0,>=2.4.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from sb3-contrib<3.0,>=2.4.0->rl_zoo3) (2.5.0a0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from rich->rl_zoo3) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from rich->rl_zoo3) (2.15.1)
# Requirement already satisfied: Mako in /home/alastor/anaconda3/lib/python3.12/site-packages (from alembic>=1.5.0->optuna>=3.0->rl_zoo3) (1.3.6)
# Requirement already satisfied: filelock in /home/alastor/anaconda3/lib/python3.12/site-packages (from huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (2024.3.1)
# Requirement already satisfied: requests in /home/alastor/anaconda3/lib/python3.12/site-packages (from huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (2.32.2)
# Requirement already satisfied: mdurl~=0.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->rl_zoo3) (0.1.0)
# Requirement already satisfied: chardet<6,>=3.0.4 in /home/alastor/anaconda3/lib/python3.12/site-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3) (4.0.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/alastor/anaconda3/lib/python3.12/site-packages (from sqlalchemy>=1.4.2->optuna>=3.0->rl_zoo3) (3.0.1)
# Requirement already satisfied: torch<3.0,>=2.3 in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (2.5.1)
# Requirement already satisfied: pandas in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (2.2.2)
# Requirement already satisfied: matplotlib in /home/alastor/anaconda3/lib/python3.12/site-packages (from stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (3.8.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.9 in /home/alastor/anaconda3/lib/python3.12/site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/alastor/anaconda3/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3) (1.16.0)
# Requirement already satisfied: networkx in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (3.2.1)
# Requirement already satisfied: jinja2 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/alastor/anaconda3/lib/python3.12/site-packages (from Mako->alembic>=1.5.0->optuna>=3.0->rl_zoo3) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/alastor/anaconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/alastor/anaconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (1.4.4)
# Requirement already satisfied: pillow>=8 in /home/alastor/anaconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (3.0.9)
# Requirement already satisfied: tzdata>=2022.7 in /home/alastor/anaconda3/lib/python3.12/site-packages (from pandas->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alastor/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/alastor/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/alastor/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alastor/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (2024.7.4)

# %% [markdown]
# Importing Modules

# %%
# to reload modules
print(sys.path)
import importlib

# import Policy Optimization Models
from stable_baselines3 import PPO
from stable_baselines3 import A2C

# import Vectorized Environments
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack

# import ALE for Atari Gameplay and gym
import ale_py
import gymnasium as gym
import numpy as np
from gymnasium import spaces
from gymnasium.wrappers import TransformReward

# helper function to evaluate how good a policy / model is
from stable_baselines3.common.evaluation import evaluate_policy

# importing callbacks
from stable_baselines3.common.callbacks import ProgressBarCallback, CheckpointCallback, CallbackList, EveryNTimesteps

# so we can record video of gameplay
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv

# imports so we can access file system
import sys
import os

# import custom helper functions
# adding helper functions to direcotry path
sys.path.append(os.path.join(os.getcwd(), 'Code'))

from Code import policy_helper
from policy_helper import create_agent
from policy_helper import gen_video
from policy_helper import variant_checkpointCallback
from policy_helper import get_doge_all_boxing_env, get_hard_hitter_boxing_env
# Out:
# ['/home/alastor/Programming/Projects/FinalProject', '/home/alastor/anaconda3/lib/python312.zip', '/home/alastor/anaconda3/lib/python3.12', '/home/alastor/anaconda3/lib/python3.12/lib-dynload', '', '/home/alastor/anaconda3/lib/python3.12/site-packages', '/home/alastor/Programming/Projects/FinalProject/Code', '/home/alastor/Programming/Projects/FinalProject/Code', '/home/alastor/Programming/Projects/FinalProject/Code', '/home/alastor/Programming/Projects/FinalProject/Code', '/home/alastor/Programming/Projects/FinalProject/Code', '/home/alastor/Programming/Projects/FinalProject/Code']

# %%
# Atari PPO Open AI Parameters
# Horizon (T)                    128
# Adam stepsize                  2.5 × 10−4 × α
# Num. epochs                    3
# Minibatch size                 32 × 8
# Discount (γ)                   0.99
# GAE parameter (λ)              0.95
# Number of actors               8
# Clipping parameter:            0.1 × α
# VF coeff. c1                   1
# Entropy coeff. c2              0.01
# open_ai_param_dict = {

# }

# this stores our hyper parameters for all atari games in general
param_dict = {
  "frame_stack": 4,             #
  "policy": 'CnnPolicy',        #
  "n_envs": 8,                  #
  "n_steps": 128,               #
  "n_epochs": 4,                #
  "batch_size": 256,            #
  "n_timesteps": 80000,         #
  "learning_rate": 2.5e-4,      #
  "clip_range": 0.1,            #
  "vf_coef": 0.5,               #
  "ent_coef": 0.01,             #
  }

# general environment
vec_env = make_atari_env("ALE/Boxing-v5", n_envs=param_dict["n_envs"], seed=0)
vec_env = VecFrameStack(vec_env, n_stack = param_dict["frame_stack"])

# model
model = PPO(
            param_dict["policy"],
            vec_env,
            verbose = 1,
            tensorboard_log = "PPO-Hit-All",
            device = "cuda",

            n_steps = param_dict["n_steps"],
            n_epochs = param_dict["n_epochs"],
            batch_size = param_dict["batch_size"],

            learning_rate = param_dict["learning_rate"],
            clip_range = param_dict["clip_range"],
            vf_coef = param_dict["vf_coef"],
            ent_coef = param_dict["ent_coef"],
            )

# getting the save and load paths
checkpoint_path = "./logs/"
model_name = "normal_model"
checkpoint_path += model_name


# defining our callbacks
# Save a checkpoint every 1000 steps
checkpoint_callback = CheckpointCallback(
  save_freq=10000,
  save_path="./logs/",
  name_prefix=checkpoint_path,
  save_replay_buffer=True,
  save_vecnormalize=True,
)

callback = CallbackList([checkpoint_callback])

# loading and training the model
vec_env.reset()
load = False
if (load):
    model = PPO.load(model_load_path)

model.set_env(vec_env)
model.learn(total_timesteps=param_dict["n_timesteps"], callback=callback, progress_bar = True, reset_num_timesteps = False)
model.save(model_save_path)
# IMPORTANT: if you get this error: LiveError: Only one live display may be active at once
# then you need to refresh the ipynb notebook
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Logging to PPO-Hit-All/PPO_0
# Output()
# -----------------------------
# | time/              |      |
# |    fps             | 157  |
# |    iterations      | 1    |
# |    time_elapsed    | 6    |
# |    total_timesteps | 1024 |
# -----------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 78
#      75     model = PPO.load(model_load_path)
#      77 model.set_env(vec_env)
# ---> 78 model.learn(total_timesteps=param_dict["n_timesteps"], callback=callback, progress_bar = True, reset_num_timesteps = False)
#      79 model.save(model_save_path)
#
# File ~/anaconda3/lib/python3.12/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File ~/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:336, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     333         assert self.ep_info_buffer is not None
#     334         self._dump_logs(iteration)
# --> 336     self.train()
#     338 callback.on_training_end()
#     340 return self
#
# File ~/anaconda3/lib/python3.12/site-packages/stable_baselines3/ppo/ppo.py:213, in PPO.train(self)
#     209 if isinstance(self.action_space, spaces.Discrete):
#     210     # Convert discrete action from float to long
#     211     actions = rollout_data.actions.long().flatten()
# --> 213 values, log_prob, entropy = self.policy.evaluate_actions(rollout_data.observations, actions)
#     214 values = values.flatten()
#     215 # Normalize advantage
#
# File ~/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/policies.py:737, in ActorCriticPolicy.evaluate_actions(self, obs, actions)
#     735     latent_pi = self.mlp_extractor.forward_actor(pi_features)
#     736     latent_vf = self.mlp_extractor.forward_critic(vf_features)
# --> 737 distribution = self._get_action_dist_from_latent(latent_pi)
#     738 log_prob = distribution.log_prob(actions)
#     739 values = self.value_net(latent_vf)
#
# File ~/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/policies.py:697, in ActorCriticPolicy._get_action_dist_from_latent(self, latent_pi)
#     694     return self.action_dist.proba_distribution(mean_actions, self.log_std)
#     695 elif isinstance(self.action_dist, CategoricalDistribution):
#     696     # Here mean_actions are the logits before the softmax
# --> 697     return self.action_dist.proba_distribution(action_logits=mean_actions)
#     698 elif isinstance(self.action_dist, MultiCategoricalDistribution):
#     699     # Here mean_actions are the flattened logits
#     700     return self.action_dist.proba_distribution(action_logits=mean_actions)
#
# File ~/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/distributions.py:288, in CategoricalDistribution.proba_distribution(self, action_logits)
#     287 def proba_distribution(self: SelfCategoricalDistribution, action_logits: th.Tensor) -> SelfCategoricalDistribution:
# --> 288     self.distribution = Categorical(logits=action_logits)
#     289     return self
#
# File ~/anaconda3/lib/python3.12/site-packages/torch/distributions/categorical.py:72, in Categorical.__init__(self, probs, logits, validate_args)
#      68 self._num_events = self._param.size()[-1]
#      69 batch_shape = (
#      70     self._param.size()[:-1] if self._param.ndimension() > 1 else torch.Size()
#      71 )
# ---> 72 super().__init__(batch_shape, validate_args=validate_args)
#
# File ~/anaconda3/lib/python3.12/site-packages/torch/distributions/distribution.py:71, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      69         valid = constraint.check(value)
#      70         if not valid.all():
# ---> 71             raise ValueError(
#      72                 f"Expected parameter {param} "
#      73                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      74                 f"of distribution {repr(self)} "
#      75                 f"to satisfy the constraint {repr(constraint)}, "
#      76                 f"but found invalid values:\n{value}"
#      77             )
#      78 super().__init__()
#
# ValueError: Expected parameter logits (Tensor of shape (256, 18)) of distribution Categorical(logits: torch.Size([256, 18])) to satisfy the constraint IndependentConstraint(Real(), 1), but found invalid values:
# tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<SubBackward0>)

# %%
print("Done Running")
# Out:
# Done Running
