# %% [markdown]
# # Installing Libraries

# %%
# final import versions

# !pip install torch
# !pip install "stable-baselines3[extra]>=2.0.0a4"
# !pip install "rl_zoo3"
# cells will automatically re-import modules when executing a new cell
# %load_ext autoreload
# %autoreload 2
print("did pip install")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (2.5.1)
# Requirement already satisfied: filelock in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from torch) (2024.10.0)
# Requirement already satisfied: setuptools in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from torch) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from jinja2->torch) (3.0.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: stable-baselines3>=2.0.0a4 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.5.0a0)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.0.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.1.3)
# Requirement already satisfied: torch<3.0,>=2.3 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.5.1)
# Requirement already satisfied: cloudpickle in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.0)
# Requirement already satisfied: pandas in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.2.3)
# Requirement already satisfied: matplotlib in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.9.3)
# Requirement already satisfied: opencv-python in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3[extra]>=2.0.0a4) (4.10.0.84)
# Requirement already satisfied: pygame in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.18.0)
# Requirement already satisfied: psutil in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3[extra]>=2.0.0a4) (6.1.0)
# Requirement already satisfied: tqdm in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3[extra]>=2.0.0a4) (4.67.1)
# Requirement already satisfied: rich in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3[extra]>=2.0.0a4) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3[extra]>=2.0.0a4) (0.10.1)
# Requirement already satisfied: pillow in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3[extra]>=2.0.0a4) (11.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.0.4)
# Requirement already satisfied: absl-py>=0.4 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.68.0)
# Requirement already satisfied: markdown>=2.6.8 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.7)
# Requirement already satisfied: packaging in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (5.29.0)
# Requirement already satisfied: setuptools>=41.0.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (75.6.0)
# Requirement already satisfied: six>1.9 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.1.3)
# Requirement already satisfied: filelock in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.16.1)
# Requirement already satisfied: networkx in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.4.2)
# Requirement already satisfied: jinja2 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.4)
# Requirement already satisfied: fsspec in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (2.18.0)
# Requirement already satisfied: colorama in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from tqdm->stable-baselines3[extra]>=2.0.0a4) (0.4.6)
# Requirement already satisfied: mdurl~=0.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a4) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.0.2)
# Defaulting to user installation because normal site-packages is not writeabledid pip install
#
# Requirement already satisfied: rl_zoo3 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (2.4.0)
# Requirement already satisfied: sb3-contrib<3.0,>=2.4.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from rl_zoo3) (2.4.0)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from rl_zoo3) (1.0.0)
# Requirement already satisfied: huggingface-sb3<4.0,>=3.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from rl_zoo3) (3.0)
# Requirement already satisfied: tqdm in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from rl_zoo3) (4.67.1)
# Requirement already satisfied: rich in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from rl_zoo3) (13.9.4)
# Requirement already satisfied: optuna>=3.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from rl_zoo3) (4.1.0)
# Requirement already satisfied: pyyaml>=5.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from rl_zoo3) (6.0.2)
# Requirement already satisfied: pytablewriter~=1.2 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from rl_zoo3) (1.2.0)
# Requirement already satisfied: shimmy~=2.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from rl_zoo3) (2.0.0)
# Requirement already satisfied: numpy>=1.21.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3) (2.1.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3) (0.0.4)
# Requirement already satisfied: huggingface-hub~=0.8 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from huggingface-sb3<4.0,>=3.0->rl_zoo3) (0.26.3)
# Requirement already satisfied: wasabi in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from huggingface-sb3<4.0,>=3.0->rl_zoo3) (1.1.3)
# Requirement already satisfied: alembic>=1.5.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from optuna>=3.0->rl_zoo3) (1.14.0)
# Requirement already satisfied: colorlog in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from optuna>=3.0->rl_zoo3) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from optuna>=3.0->rl_zoo3) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from optuna>=3.0->rl_zoo3) (2.0.36)
# Requirement already satisfied: setuptools>=38.3.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from pytablewriter~=1.2->rl_zoo3) (75.6.0)
# Requirement already satisfied: DataProperty<2,>=1.0.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from pytablewriter~=1.2->rl_zoo3) (1.0.1)
# Requirement already satisfied: mbstrdecoder<2,>=1.0.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from pytablewriter~=1.2->rl_zoo3) (1.1.3)
# Requirement already satisfied: pathvalidate<4,>=2.3.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from pytablewriter~=1.2->rl_zoo3) (3.2.1)
# Requirement already satisfied: tabledata<2,>=1.3.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from pytablewriter~=1.2->rl_zoo3) (1.3.3)
# Requirement already satisfied: tcolorpy<1,>=0.0.5 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from pytablewriter~=1.2->rl_zoo3) (0.1.6)
# Requirement already satisfied: typepy<2,>=1.3.2 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3) (1.3.2)
# Requirement already satisfied: stable-baselines3<3.0,>=2.4.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from sb3-contrib<3.0,>=2.4.0->rl_zoo3) (2.5.0a0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from rich->rl_zoo3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from rich->rl_zoo3) (2.18.0)
# Requirement already satisfied: colorama in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from tqdm->rl_zoo3) (0.4.6)
# Requirement already satisfied: Mako in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from alembic>=1.5.0->optuna>=3.0->rl_zoo3) (1.3.6)
# Requirement already satisfied: filelock in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (2024.10.0)
# Requirement already satisfied: requests in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (2.32.3)
# Requirement already satisfied: mdurl~=0.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from markdown-it-py>=2.2.0->rich->rl_zoo3) (0.1.2)
# Requirement already satisfied: chardet<6,>=3.0.4 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3) (5.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from sqlalchemy>=1.4.2->optuna>=3.0->rl_zoo3) (3.1.1)
# Requirement already satisfied: torch<3.0,>=2.3 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (2.5.1)
# Requirement already satisfied: pandas in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (2.2.3)
# Requirement already satisfied: matplotlib in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (3.9.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.9 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3) (2024.2)
# Requirement already satisfied: six>=1.5 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3) (1.16.0)
# Requirement already satisfied: networkx in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (3.4.2)
# Requirement already satisfied: jinja2 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from Mako->alembic>=1.5.0->optuna>=3.0->rl_zoo3) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (1.4.7)
# Requirement already satisfied: pillow>=8 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (3.2.0)
# Requirement already satisfied: tzdata>=2022.7 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from pandas->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in \\ufilesrv\homes\rkoppolu\windowsfolders\appdatacsenetid\python\python312\site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (2024.8.30)

# %% [markdown]
# # Imports

# %%
# to reload modules
import importlib

import math

# import Policy Optimization Models
from stable_baselines3 import PPO
from stable_baselines3 import A2C

# import Vectorized Environments
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack

# import ALE for Atari Gameplay and gym
import ale_py
import gymnasium as gym
import numpy as np
from gymnasium import spaces
from gymnasium.wrappers import TransformReward

# helper function to evaluate how good a policy / model is
from stable_baselines3.common.evaluation import evaluate_policy

# importing callbacks
from stable_baselines3.common.callbacks import ProgressBarCallback, CheckpointCallback, CallbackList, EveryNTimesteps

# so we can record video of gameplay
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv

# imports so we can access file system
import sys
import os

# import custom helper functions
# adding helper functions to direcotry path
sys.path.append(os.path.join(os.getcwd(), 'Code'))

from Code import policy_helper
from policy_helper import create_agent
from policy_helper import gen_video
from policy_helper import variant_checkpointCallback
from policy_helper import get_doge_all_boxing_env, get_hard_hitter_boxing_env

print("did imports")
# Out:
# did imports

# %% [markdown]
# # Training Models

# %%
# Atari PPO Open AI Parameters
# Horizon (T)                    128
# Adam stepsize                  2.5 × 10−4 × α
# Num. epochs                    3
# Minibatch size                 32 × 8
# Discount (γ)                   0.99
# GAE parameter (λ)              0.95
# Number of actors               8
# Clipping parameter:            0.1 × α
# VF coeff. c1                   1
# Entropy coeff. c2              0.01
# open_ai_param_dict = {

# }

# this stores our hyper parameters for all atari games in general
param_dict = {
  "frame_stack": 4,             #
  "policy": 'CnnPolicy',        #
  "n_envs": 8,                  #
  "n_steps": 128,               #
  "n_epochs": 4,                #
  "batch_size": 256,            #
  "n_timesteps": 5e6,           #
  "learning_rate": 2.5e-4,      #
  "clip_range": 0.1,            #
  "vf_coef": 0.5,               #
  "ent_coef": 0.01,             #
  }

# general environment
# vec_env = make_atari_env("ALE/Boxing-v5", n_envs=param_dict["n_envs"], seed=0)
# vec_env = VecFrameStack(vec_env, n_stack = param_dict(["frame_stack"])

vec_env = make_atari_env(get_dodge_soft_boxing_env, n_envs=param_dict["n_envs"], seed=0)
vec_env = VecFrameStack(vec_env, n_stack = param_dict["frame_stack"])

# getting the save and load paths
model_name = "dodge_soft_model"
use_checkpoint = False
model_save_path = "Saved_Models/" + model_name
tensor_board_name = "Tensorboard/" + model_name
if (use_checkpoint):
    #Checkpoints/normal_model/normal_model_33744_steps.zip
    model_load_path = "./Checkpoints/" + model_name + None
else:
    model_load_path = model_save_path
checkpoint_path = model_name

# defining our callbacks
# Save a checkpoint every k steps
checkpoint_callback = CheckpointCallback(
  save_freq=max(100000 // param_dict["n_envs"], 1),
  save_path="./Checkpoints/" + model_name,
  name_prefix=checkpoint_path,
  save_replay_buffer=True,
  save_vecnormalize=True,
)

callback = CallbackList([checkpoint_callback])

# loading and training the model
vec_env.reset()
load = False
if (load):
    model = PPO.load(model_load_path)
else:
    # model
    model = PPO(
                param_dict["policy"],
                vec_env,
                verbose = 1,
                tensorboard_log = tensor_board_name,
                device = "cuda",
    
                n_steps = param_dict["n_steps"],
                n_epochs = param_dict["n_epochs"],
                batch_size = param_dict["batch_size"],
    
                learning_rate = param_dict["learning_rate"],
                clip_range = param_dict["clip_range"],
                vf_coef = param_dict["vf_coef"],
                ent_coef = param_dict["ent_coef"],
                )
model.set_env(vec_env)

# training
model.learn(total_timesteps=param_dict["n_timesteps"], callback=callback, progress_bar = True, reset_num_timesteps = False)
model.save(model_save_path)
# IMPORTANT: if you get this error: LiveError: Only one live display may be active at once
# then you need to refresh the ipynb notebook
# Out:
# 4.0

# %% [markdown]
# # Training Ensemble

# %%
from ensembled_rl import EnsembledActorCritic
vec_env = make_atari_env("ALE/Boxing-v5", n_envs=8, seed=0)
vec_env = VecFrameStack(vec_env, n_stack = 4)

should_delete = ""
# specify a unique id if you want a unique save, instead of overwriting
unique_num = ""
unique_name = "ensemble_aggressive"
unique_id = unique_num + unique_name

special_parts = should_delete + unique_id
root_dir = '/content/drive/My Drive/'+ FOLDERNAME + "/Saved_Models/"
save_name = "general_atari_ppo_boxing"+special_parts
model_save_path = root_dir + save_name
model_load_path = root_dir + save_name + ".zip"

param_dict = {
  "frame_stack": 4,
  "policy": 'CnnPolicy',
  "n_envs": 8,
  "n_steps": 128,
  "n_epochs": 4,
  "batch_size": 256,
  "n_timesteps": float(5.8e5),
  "learning_rate": 2.5e-4,
  "clip_range": 0.1,
  "vf_coef": 0.5,
  "ent_coef": 0.01,
  }

model = PPO(
             EnsembledActorCritic,
             vec_env,
             verbose = 1,
             tensorboard_log = "PPO-Ensemble",
             device = "cpu",
             n_steps = param_dict["n_steps"],
             n_epochs = param_dict["n_epochs"],
             batch_size = param_dict["batch_size"],
             learning_rate = param_dict["learning_rate"],
             clip_range = param_dict["clip_range"],
             vf_coef = param_dict["vf_coef"],
             ent_coef = param_dict["ent_coef"],
             policy_kwargs={
                'base_models': [
                    root_dir + 'general_atari_ppo_boxing',
                    root_dir + 'general_atari_ppo_boxingaggressive_pure'
                ],
                'ensemble_type': 'mlp',
                'action_size': 18,
             }
             )

model.learn(total_timesteps=param_dict["n_timesteps"], progress_bar = True, reset_num_timesteps = False)
model.save(model_save_path)

# %%
print("Done Running")
